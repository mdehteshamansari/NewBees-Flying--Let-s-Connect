# %% [markdown]
# <a href="https://colab.research.google.com/github/mdehteshamansari/NewBees-Flying--Let-s-Connect/blob/main/final_Voice_Cloning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cloning the repository
# !git clone https://github.com/misbah4064/Real-Time-Voice-Cloning.git
# Out:
# Cloning into 'Real-Time-Voice-Cloning'...
# remote: Enumerating objects: 2453, done.
# remote: Total 2453 (delta 0), reused 0 (delta 0), pack-reused 2453
# Receiving objects: 100% (2453/2453), 363.73 MiB | 33.05 MiB/s, done.
# Resolving deltas: 100% (1341/1341), done.

# %%
# Changing the current directory to the repository's directory
# %cd Real-Time-Voice-Cloning/
# Out:
# /content/Real-Time-Voice-Cloning/Real-Time-Voice-Cloning

# %%
# Installing the dependencies
# !pip install -q -r requirements.txt
# !apt-get install -qq libportaudio2

# %%
# Downloading pretrained data and unzipping it
# !gdown https://drive.google.com/uc?id=1n1sPXvT34yXFLT47QZA6FIRGrwMeSsZc
# !unzip pretrained.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1n1sPXvT34yXFLT47QZA6FIRGrwMeSsZc
# To: /content/Real-Time-Voice-Cloning/Real-Time-Voice-Cloning/pretrained.zip
# 100% 384M/384M [00:02<00:00, 132MB/s]
# Archive:  pretrained.zip
#    creating: encoder/saved_models/
#   inflating: encoder/saved_models/pretrained.pt
#    creating: synthesizer/saved_models/
#    creating: synthesizer/saved_models/logs-pretrained/
#    creating: synthesizer/saved_models/logs-pretrained/taco_pretrained/
#  extracting: synthesizer/saved_models/logs-pretrained/taco_pretrained/checkpoint
#   inflating: synthesizer/saved_models/logs-pretrained/taco_pretrained/tacotron_model.ckpt-278000.data-00000-of-00001
#   inflating: synthesizer/saved_models/logs-pretrained/taco_pretrained/tacotron_model.ckpt-278000.index
#   inflating: synthesizer/saved_models/logs-pretrained/taco_pretrained/tacotron_model.ckpt-278000.meta
#    creating: vocoder/saved_models/
#    creating: vocoder/saved_models/pretrained/
# ...

# %%
# Initializing all the encoder libraries
from IPython.display import Audio
from IPython.utils import io
from synthesizer.inference import Synthesizer
from encoder import inference as encoder
from vocoder import inference as vocoder
from pathlib import Path
import numpy as np
import librosa
encoder_weights = Path("encoder/saved_models/pretrained.pt")
vocoder_weights = Path("vocoder/saved_models/pretrained/pretrained.pt")
syn_dir = Path("synthesizer/saved_models/logs-pretrained/taco_pretrained")
encoder.load_model(encoder_weights)
synthesizer = Synthesizer(syn_dir)
vocoder.load_model(vocoder_weights)
# Out:
# Loaded encoder "pretrained.pt" trained to step 1564501
# Found synthesizer "pretrained" trained to step 278000
# Building Wave-RNN
# Trainable Parameters: 4.481M
# Loading model weights at vocoder/saved_models/pretrained/pretrained.pt

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Ask any question you have in your mind it'll be solved.

# %%
import openai
def gpt3(stext):
     openai.api_key = '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'
     response = openai.Completion.create(
       engine= "davinci-instruct-beta",
       prompt=stext,
              temperature=0.1,
              max_tokens=1000,
              top_p=1,
              frequency_penalty=0,
              presence_penalty=0
     )
     content = response.choices[0].text.split('.')
     print(content)
     return response.choices[0].text
query=input()
res=gpt3(query)
print(res)
# Out:
# write me a cold email for the job of data analysts.
# ['\n\nDear Sir or Madam,\n\nI am a recent graduate with a degree in mathematics and statistics', ' I am looking for a job as a data analyst and I am very interested in your company', ' I have a strong background in data analysis and I am confident that I would be a valuable asset to your company', ' I am available for an interview at your convenience', '\n\nSincerely,\n\nJohn Smith']
#
#
# Dear Sir or Madam,
#
# I am a recent graduate with a degree in mathematics and statistics. I am looking for a job as a data analyst and I am very interested in your company. I have a strong background in data analysis and I am confident that I would be a valuable asset to your company. I am available for an interview at your convenience.
#
# Sincerely,
#
# John Smith

# %% [markdown]
# If you want to chat with some famous peronality type:- "chat with me like your_personality".

# %%
import os
import openai

openai.api_key = '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'

start_sequence = "\nAI:"
restart_sequence = "\nHuman: "
t=1
while(t!=0):
    stext=input()
    response = openai.Completion.create(
     model="text-davinci-002",
     prompt="The following is a conversation with an AI assistant. The assistant is helpful, creative, clever, and very friendly.\n\nHuman: Hello, who are you?\nAI: I am an AI created by OpenAI. How can I help you today?\nHuman: "+stext,
     temperature=0.9,
     max_tokens=150,
     top_p=1,
     frequency_penalty=0,
     presence_penalty=0.6,
     stop=[" Human:", " AI:"]
    )
    print(response.choices[0].text.split('.'))
    k=input("t=")
    t=k
# Out:
# chat with me as Ratan Tata.
# ["\n\n\n\nHi there! I'm Ratan Tata, chairman of the Tata Group", " As one of India's most prominent and respected businessmen, I am always happy to chat and help out where I can", ' What can I do for you today?']
# t=
# tell me about tata steel.
# ['\n\n\nTata Steel is an Indian multinational steel-making company headquartered in Mumbai, Maharashtra, India', " It is the world's second-most geographically diversified steel producer", '']
# t=
# what can i learn from you?
# ['\n\nAI: I can help you with anything you need to know', ' Whether you want to learn about the history of artificial intelligence or the latest breakthroughs in the field, I can provide you with reliable and up-to-date information', ' I can also help you develop your own skills in artificial intelligence by providing resources and advice', '']
# t=
# tell me about jamshedpur.
# ...

# %% [markdown]
# Text To Speech implementation of the model in the voice of Elon Musk

# %%
def voice(text):
  in_fpath = Path("Elonmmusk.wav")
  reprocessed_wav = encoder.preprocess_wav(in_fpath)
  original_wav, sampling_rate = librosa.load(in_fpath)
  preprocessed_wav = encoder.preprocess_wav(original_wav, sampling_rate)
  embed = encoder.embed_utterance(preprocessed_wav)
  with io.capture_output() as captured:
    specs = synthesizer.synthesize_spectrograms([text], [embed])
  generated_wav = vocoder.infer_waveform(specs[0])
  generated_wav = np.pad(generated_wav, (0, synthesizer.sample_rate), mode="constant")
  display(Audio(generated_wav, rate=synthesizer.sample_rate))

# %%
import openai
def gpt3(stext):
     openai.api_key = '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'
     response = openai.Completion.create(
       engine= "davinci-instruct-beta",
       prompt=stext,
              temperature=0.1,
              max_tokens=1000,
              top_p=1,
              frequency_penalty=0,
              presence_penalty=0
     )
     content = response.choices[0].text.split('.')
     rf=voice(response.choices[0].text)
     return response.choices[0].text
query=input()
res=gpt3(query)
print(res)
# Out:
# tell me about chicago.
# {| ████████████████ 95000/96000 | Batch Size: 10 | Gen Rate: 11.4kHz | }
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Chicago is a city in the state of Illinois. It is the third-largest city in the United States, and the largest city in the Midwest.
